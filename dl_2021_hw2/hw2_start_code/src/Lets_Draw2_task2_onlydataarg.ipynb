# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
name = "Task2_modelMyhighwayonlydataarg"

LA = np.load(name+"_Loss_Acc.npy")

# %%
plt.title(name+' Loss')
plt.plot(LA[:,0], color='aqua', label='Train Loss')
plt.plot(LA[:,2], color='violet', label='Valid Loss')
plt.legend()
plt.show()

# %%
plt.title(name+" Acc")
plt.plot(LA[:,1], color='aqua', label='Train Acc')
plt.plot(LA[:,3], color='violet', label='Valid Acc')
plt.legend()
plt.show()

# %%
name2 = "Task2_modelMyhighway"

LA2 = np.load(name2+"_Loss_Acc.npy")

# %%
plt.title(name+' vs '+name2+' Loss')
plt.plot(LA[:,0], color='aqua', label=name+' Train Loss')
plt.plot(LA[:,2], color='violet', label=name+' Valid Loss')
plt.plot(LA2[:,0], color='dodgerblue', label=name2+' Train Loss')
plt.plot(LA2[:,2], color='purple', label=name2+' Valid Loss')
plt.legend()
plt.xlabel("Epochs (x10)") 
plt.ylabel("Accuracy") 
plt.show()

# %%
plt.title(name+' vs '+name2+" Acc")
plt.plot(LA[:,1], color='aqua', label=name+' Train Acc')
plt.plot(LA[:,3], color='violet', label=name+' Valid Acc')
plt.plot(LA2[:,1], color='dodgerblue', label=name2+' Train Acc')
plt.plot(LA2[:,3], color='purple', label=name2+' Valid Acc')
plt.legend()
plt.xlabel("Epochs (x10)") 
plt.ylabel("Accuracy") 
plt.show()

# %%
shiftrate = 10/8
shiftrate

sft = []
for i in range(len(LA2)): sft.append(shiftrate*(i+0.5))

# %%
plt.title(name+' vs '+name2+' Loss')
plt.plot(LA[:,0], color='aqua', label=name+' Train Loss')
plt.plot(LA[:,2], color='violet', label=name+' Valid Loss')
plt.plot(sft,LA2[:,0], color='dodgerblue', label=name2+' Train Loss')
plt.plot(sft,LA2[:,2], color='purple', label=name2+' Valid Loss')
plt.legend()
plt.show()

# %%
# plt.title(name+' vs '+name2+" Acc")
plt.title("DataAug"+' vs '+"Origin"+" Acc")
idx = []
for i in range(len(LA)):
    idx.append(i)
p1 = 30
p2 = int(p1/shiftrate)
lim = 125
plt.plot(idx[p1:lim],LA[p1:lim,1], color='aqua', label='DataAug Train Acc')#name+' Train Acc')
plt.plot(idx[p1:lim],LA[p1:lim,3], color='violet', label='DataAug Valid Acc')#name+' Valid Acc')
plt.plot(sft[p2:],LA2[p2:,1], color='dodgerblue', label='Origin Train Acc')#name2+' Train Acc')
plt.plot(sft[p2:],LA2[p2:,3], color='purple', label='Origin Valid Acc')#name2+' Valid Acc')
plt.legend()
plt.scatter(40,0.77)
plt.show()

# %%
import numpy as np
tmppp = np.load("Task5_modelMyhighway_Conf_Mat.npy")
tmppp[-1]
# Out:
# array([[553,   2,   4,   2,   0,   4,   3,   0,   5,   0],
#        [  0, 567,   1,   0,   0,   1,   0,   0,   0,   1],
#        [  5,   3, 564,   1,   1,   3,  11,   1,   2,   0],
#        [  2,   0,   3, 484,   7,   0,   7,  11,   8,   0],
#        [  1,   0,   0,   1, 490,   0,   1,  23,   0,   0],
#        [  7,  11,   7,   0,   0, 394,   4,   1,   5,   0],
#        [ 27,   1,  36,   4,   3,   3, 443,   4,   0,   0],
#        [  0,   0,   0,   0,   2,   0,   0, 575,   0,   0],
#        [ 14,   0,   0,   7,   6,   2,   2,   0, 476,   0],
#        [  5,   0,   1,   0,   0,   1,   0,   0,  10, 577]])

# %%
import numpy as np
tmppp = np.load("Task5_modelResnet_Conf_Mat.npy")
tmppp[-1]
# Out:
# array([[471,   9,   9,   1,   0,   7,  39,  11,  25,   1],
#        [  0, 545,   4,   0,   0,  12,   0,   0,   5,   4],
#        [ 15,   5, 351,   2,   1,   8,  84, 107,  11,   7],
#        [ 32,   3,  11, 196,   8,   7,  52, 135,  78,   0],
#        [  0,   3,   0,   3, 322,   0,   1, 185,   2,   0],
#        [ 10,  19,  11,   6,   1, 301,  29,   4,  48,   0],
#        [ 20,   1,  22,  11,   1,  11, 358,  82,  15,   0],
#        [  0,   0,   3,   0,   2,   0,   4, 568,   0,   0],
#        [ 14,  16,   3,  23,   6,  11,  15,  18, 400,   1],
#        [ 17,  66,  16,   0,   0,   4,   1,   0,  40, 450]])
